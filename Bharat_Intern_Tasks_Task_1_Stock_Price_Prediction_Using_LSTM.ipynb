# %%
#importing libraries to be used
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/content/GOOG.csv') # Import dataset file
df.head(10) # Fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %%
df.shape
# Out:
# (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']]
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0]))
df.set_index('date',drop=True,inplace=True)
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# Plotting open and closing price on date index
fig , ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='red')
ax[0].set_xlabel('Date',size=10)
ax[0].set_ylabel('Price',size=10)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='yellow')
ax[1].set_xlabel('Date',size=10)
ax[1].set_ylabel('Price',size=10)
ax[1].legend()

fig.show()

# %%
mms = MinMaxScaler()
df[df.columns] = mms.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
train = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
train
# Out:
# 944

# %%
train_data = df[:train]
test_data  = df[train:]
train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Create a fun for training & testing
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ##CREATING LSTM MODEL

# %%
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))
model.add(Dropout(0.1))
model.add(LSTM(units=50))
model.add(Dense(2))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 50, 50)            10600
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 8s 100ms/step - loss: 0.0053 - mean_absolute_error: 0.0506 - val_loss: 0.0108 - val_mean_absolute_error: 0.0825
# Epoch 2/100
# 28/28 [==============================] - 2s 75ms/step - loss: 6.7863e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0050 - val_mean_absolute_error: 0.0549
# Epoch 3/100
# 28/28 [==============================] - 3s 108ms/step - loss: 4.3925e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0046 - val_mean_absolute_error: 0.0538
# Epoch 4/100
# 28/28 [==============================] - 2s 62ms/step - loss: 4.2294e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0054 - val_mean_absolute_error: 0.0591
# Epoch 5/100
# 28/28 [==============================] - 2s 61ms/step - loss: 4.0591e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0036 - val_mean_absolute_error: 0.0458
# Epoch 6/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.8942e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0039 - val_mean_absolute_error: 0.0484
# Epoch 7/100
# 28/28 [==============================] - 2s 68ms/step - loss: 3.9664e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0042 - val_mean_absolute_error: 0.0504
# Epoch 8/100
# 28/28 [==============================] - 2s 60ms/step - loss: 3.7671e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0052 - val_mean_absolute_error: 0.0578
# Epoch 9/100
# 28/28 [==============================] - 3s 113ms/step - loss: 3.5925e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0057 - val_mean_absolute_error: 0.0612
# Epoch 10/100
# 28/28 [==============================] - 3s 122ms/step - loss: 3.9356e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0040 - val_mean_absolute_error: 0.0490
# Epoch 11/100
# 28/28 [==============================] - 2s 67ms/step - loss: 3.7278e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0028 - val_mean_absolute_error: 0.0398
# Epoch 12/100
# 28/28 [==============================] - 2s 62ms/step - loss: 3.3836e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0036 - val_mean_absolute_error: 0.0464
# Epoch 13/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.9212e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0069 - val_mean_absolute_error: 0.0679
# Epoch 14/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.7167e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0031 - val_mean_absolute_error: 0.0425
# Epoch 15/100
# 28/28 [==============================] - 3s 101ms/step - loss: 3.4521e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0029 - val_mean_absolute_error: 0.0404
# Epoch 16/100
# 28/28 [==============================] - 2s 67ms/step - loss: 3.4834e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0036 - val_mean_absolute_error: 0.0462
# Epoch 17/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.1347e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0045 - val_mean_absolute_error: 0.0535
# Epoch 18/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.9014e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0043 - val_mean_absolute_error: 0.0517
# Epoch 19/100
# 28/28 [==============================] - 2s 61ms/step - loss: 3.0174e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0061 - val_mean_absolute_error: 0.0633
# Epoch 20/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.9346e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0029 - val_mean_absolute_error: 0.0409
# Epoch 21/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.6783e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0026 - val_mean_absolute_error: 0.0380
# Epoch 22/100
# 28/28 [==============================] - 4s 137ms/step - loss: 2.9966e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0036 - val_mean_absolute_error: 0.0473
# Epoch 23/100
# 28/28 [==============================] - 4s 147ms/step - loss: 2.7881e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0036 - val_mean_absolute_error: 0.0465
# Epoch 24/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.7006e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0042 - val_mean_absolute_error: 0.0515
# Epoch 25/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.7482e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357
# Epoch 26/100
# 28/28 [==============================] - 2s 84ms/step - loss: 2.6819e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 27/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.5089e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0034 - val_mean_absolute_error: 0.0456
# Epoch 28/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.4249e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0031 - val_mean_absolute_error: 0.0440
# Epoch 29/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.6686e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0049 - val_mean_absolute_error: 0.0566
# Epoch 30/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.4393e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0047 - val_mean_absolute_error: 0.0556
# Epoch 31/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.5490e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
# Epoch 32/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.2954e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0043 - val_mean_absolute_error: 0.0529
# Epoch 33/100
# 28/28 [==============================] - 3s 106ms/step - loss: 2.6191e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0035 - val_mean_absolute_error: 0.0474
# Epoch 34/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.3439e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0025 - val_mean_absolute_error: 0.0389
# Epoch 35/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.3727e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0025 - val_mean_absolute_error: 0.0393
# Epoch 36/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.2797e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0027 - val_mean_absolute_error: 0.0413
# Epoch 37/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.1346e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0024 - val_mean_absolute_error: 0.0382
# Epoch 38/100
# 28/28 [==============================] - 2s 67ms/step - loss: 2.2088e-04 - mean_absolute_error: 0.0107 - val_loss: 9.3178e-04 - val_mean_absolute_error: 0.0223
# Epoch 39/100
# 28/28 [==============================] - 2s 80ms/step - loss: 2.2878e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 40/100
# 28/28 [==============================] - 2s 88ms/step - loss: 2.2710e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0022 - val_mean_absolute_error: 0.0364
# Epoch 41/100
# 28/28 [==============================] - 2s 87ms/step - loss: 2.1301e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0026 - val_mean_absolute_error: 0.0398
# Epoch 42/100
# 28/28 [==============================] - 2s 78ms/step - loss: 2.0162e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0030 - val_mean_absolute_error: 0.0439
# Epoch 43/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.0251e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0014 - val_mean_absolute_error: 0.0274
# Epoch 44/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.3133e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 45/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.9660e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0023 - val_mean_absolute_error: 0.0365
# Epoch 46/100
# 28/28 [==============================] - 2s 88ms/step - loss: 2.0400e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0024 - val_mean_absolute_error: 0.0375
# Epoch 47/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.8930e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0259
# Epoch 48/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.9419e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268
# Epoch 49/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.8865e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0037 - val_mean_absolute_error: 0.0498
# Epoch 50/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.8011e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0016 - val_mean_absolute_error: 0.0298
# Epoch 51/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.7293e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355
# Epoch 52/100
# 28/28 [==============================] - 3s 105ms/step - loss: 1.8644e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0020 - val_mean_absolute_error: 0.0347
# Epoch 53/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.7937e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338
# Epoch 54/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.7673e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0041 - val_mean_absolute_error: 0.0534
# Epoch 55/100
# 28/28 [==============================] - 3s 90ms/step - loss: 1.9971e-04 - mean_absolute_error: 0.0101 - val_loss: 9.5675e-04 - val_mean_absolute_error: 0.0225
# Epoch 56/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.8534e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 57/100
# 28/28 [==============================] - 2s 72ms/step - loss: 1.8136e-04 - mean_absolute_error: 0.0097 - val_loss: 8.0846e-04 - val_mean_absolute_error: 0.0208
# Epoch 58/100
# 28/28 [==============================] - 3s 101ms/step - loss: 1.6085e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 59/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.6942e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0016 - val_mean_absolute_error: 0.0302
# Epoch 60/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.5769e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0017 - val_mean_absolute_error: 0.0315
# Epoch 61/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.5755e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 62/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.7864e-04 - mean_absolute_error: 0.0099 - val_loss: 6.8795e-04 - val_mean_absolute_error: 0.0194
# Epoch 63/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.6810e-04 - mean_absolute_error: 0.0095 - val_loss: 9.7465e-04 - val_mean_absolute_error: 0.0231
# Epoch 64/100
# 28/28 [==============================] - 3s 121ms/step - loss: 1.5118e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 65/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.6139e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0017 - val_mean_absolute_error: 0.0315
# Epoch 66/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.5055e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0021 - val_mean_absolute_error: 0.0385
# Epoch 67/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.5759e-04 - mean_absolute_error: 0.0090 - val_loss: 8.9696e-04 - val_mean_absolute_error: 0.0221
# Epoch 68/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.4119e-04 - mean_absolute_error: 0.0085 - val_loss: 6.8607e-04 - val_mean_absolute_error: 0.0190
# Epoch 69/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.7240e-04 - mean_absolute_error: 0.0096 - val_loss: 8.4227e-04 - val_mean_absolute_error: 0.0220
# Epoch 70/100
# 28/28 [==============================] - 2s 86ms/step - loss: 1.4640e-04 - mean_absolute_error: 0.0086 - val_loss: 5.2700e-04 - val_mean_absolute_error: 0.0167
# Epoch 71/100
# 28/28 [==============================] - 3s 95ms/step - loss: 1.3526e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 72/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.3617e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0013 - val_mean_absolute_error: 0.0289
# Epoch 73/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.3374e-04 - mean_absolute_error: 0.0084 - val_loss: 9.3890e-04 - val_mean_absolute_error: 0.0232
# Epoch 74/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.2578e-04 - mean_absolute_error: 0.0081 - val_loss: 7.1604e-04 - val_mean_absolute_error: 0.0196
# Epoch 75/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.4271e-04 - mean_absolute_error: 0.0086 - val_loss: 6.5468e-04 - val_mean_absolute_error: 0.0190
# Epoch 76/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.3024e-04 - mean_absolute_error: 0.0082 - val_loss: 9.3319e-04 - val_mean_absolute_error: 0.0229
# Epoch 77/100
# 28/28 [==============================] - 3s 100ms/step - loss: 1.1882e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 78/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.2518e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0019 - val_mean_absolute_error: 0.0368
# Epoch 79/100
# 28/28 [==============================] - 2s 61ms/step - loss: 1.4226e-04 - mean_absolute_error: 0.0087 - val_loss: 5.9856e-04 - val_mean_absolute_error: 0.0175
# Epoch 80/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.3359e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 81/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.3554e-04 - mean_absolute_error: 0.0084 - val_loss: 7.0530e-04 - val_mean_absolute_error: 0.0195
# Epoch 82/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1111e-04 - mean_absolute_error: 0.0075 - val_loss: 8.0379e-04 - val_mean_absolute_error: 0.0209
# Epoch 83/100
# 28/28 [==============================] - 2s 78ms/step - loss: 1.1423e-04 - mean_absolute_error: 0.0077 - val_loss: 6.0618e-04 - val_mean_absolute_error: 0.0176
# Epoch 84/100
# 28/28 [==============================] - 3s 91ms/step - loss: 1.2942e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 85/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.1598e-04 - mean_absolute_error: 0.0075 - val_loss: 7.6552e-04 - val_mean_absolute_error: 0.0209
# Epoch 86/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1682e-04 - mean_absolute_error: 0.0077 - val_loss: 8.4491e-04 - val_mean_absolute_error: 0.0214
# Epoch 87/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.2109e-04 - mean_absolute_error: 0.0077 - val_loss: 9.5563e-04 - val_mean_absolute_error: 0.0238
# Epoch 88/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.1625e-04 - mean_absolute_error: 0.0077 - val_loss: 4.7126e-04 - val_mean_absolute_error: 0.0158
# Epoch 89/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.2530e-04 - mean_absolute_error: 0.0082 - val_loss: 6.1415e-04 - val_mean_absolute_error: 0.0177
# Epoch 90/100
# 28/28 [==============================] - 2s 89ms/step - loss: 1.1552e-04 - mean_absolute_error: 0.0075 - val_loss: 6.8216e-04 - val_mean_absolute_error: 0.0189
# Epoch 91/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.2496e-04 - mean_absolute_error: 0.0079 - val_loss: 7.0975e-04 - val_mean_absolute_error: 0.0188
# Epoch 92/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.1482e-04 - mean_absolute_error: 0.0076 - val_loss: 6.0782e-04 - val_mean_absolute_error: 0.0177
# Epoch 93/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.0343e-04 - mean_absolute_error: 0.0072 - val_loss: 8.1937e-04 - val_mean_absolute_error: 0.0209
# Epoch 94/100
# 28/28 [==============================] - 2s 71ms/step - loss: 1.0820e-04 - mean_absolute_error: 0.0073 - val_loss: 5.8540e-04 - val_mean_absolute_error: 0.0177
# Epoch 95/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.0208e-04 - mean_absolute_error: 0.0071 - val_loss: 8.2942e-04 - val_mean_absolute_error: 0.0223
# Epoch 96/100
# 28/28 [==============================] - 2s 71ms/step - loss: 1.2414e-04 - mean_absolute_error: 0.0081 - val_loss: 4.7631e-04 - val_mean_absolute_error: 0.0158
# Epoch 97/100
# 28/28 [==============================] - 3s 104ms/step - loss: 1.1504e-04 - mean_absolute_error: 0.0076 - val_loss: 6.7287e-04 - val_mean_absolute_error: 0.0186
# Epoch 98/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.0759e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 99/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1910e-04 - mean_absolute_error: 0.0077 - val_loss: 4.1069e-04 - val_mean_absolute_error: 0.0147
# Epoch 100/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.1008e-04 - mean_absolute_error: 0.0074 - val_loss: 6.0517e-04 - val_mean_absolute_error: 0.0175

# %%
#predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 18ms/step
# array([[0.40973485, 0.4111878 ],
#        [0.40851665, 0.40984887],
#        [0.40274155, 0.40396813],
#        [0.40854567, 0.4098061 ],
#        [0.4126435 , 0.41398105]], dtype=float32)

# %%
test_inverse_predicted = mms.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1430.6156, 1430.3308],
#        [1428.3572, 1427.8494],
#        [1417.6506, 1416.9503],
#        [1428.411 , 1427.77  ],
#        [1436.008 , 1435.5076]], dtype=float32)

# %% [markdown]
# ##VISUALIZING ACTUAL VS PREDICTED DATA

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = mms.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1430.615601      1430.330811
# 2020-05-28  1396.86  1416.73     1428.357178      1427.849365
# 2020-05-29  1416.94  1428.92     1417.650635      1416.950317
# 2020-06-01  1418.39  1431.82     1428.411011      1427.770020
# 2020-06-02  1430.55  1439.22     1436.008057      1435.507568

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=10)
plt.ylabel('Stock Price',size=10)
plt.title('Actual vs Predicted for open price',size=10)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ##REDICTING

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2373.870605      2470.873291
# 2021-06-10  2494.01  2521.60     2382.017090      2480.645752
# 2021-06-11  2524.92  2513.93     2395.521484      2495.679199
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
# Creating a DataFrame and filling values
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 50ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = mms.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
